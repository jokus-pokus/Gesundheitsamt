# %%
import pandas as pd
from matplotlib import pyplot as plt
from fbprophet import Prophet
from DatenSammlung import DatenVergangenheitHolen, FeiertageHolen, WetterVorhersageNBG
from DatenVerarbeitung import DatenVerarbeitung

from datetime import date
# Out:
# Importing plotly failed. Interactive plots will not work.
# Today's date: 2021-04-15
# Today's date: 2021-04-15

# %%
today = date.today()

# %%
df = DatenVerarbeitung()
# Out:
# start_date and end_date filtering limited to defined periods [<Period.HISTORICAL: 'historical'>, <Period.RECENT: 'recent'>, <Period.NOW: 'now'>]
# The combination of kl, daily, now is invalid.
# 100%|██████████| 1/1 [00:02<00:00,  2.89s/it]
# C:\Users\j_kei\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3417: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
WetterVorhersage = WetterVorhersageNBG();
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:   0%|          | 0.00/35.4M [00:00<?, ?iB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:   2%|▏         | 768k/35.4M [00:00<00:04, 7.71MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:   4%|▍         | 1.46M/35.4M [00:00<00:04, 7.61MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:   6%|▌         | 2.17M/35.4M [00:00<00:04, 7.54MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:   8%|▊         | 2.88M/35.4M [00:00<00:04, 7.47MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  10%|█         | 3.58M/35.4M [00:00<00:04, 7.40MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  12%|█▏        | 4.30M/35.4M [00:00<00:04, 7.42MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  14%|█▍        | 4.92M/35.4M [00:00<00:04, 7.01MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  16%|█▌        | 5.74M/35.4M [00:00<00:04, 7.42MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  18%|█▊        | 6.44M/35.4M [00:00<00:04, 7.36MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  20%|██        | 7.15M/35.4M [00:01<00:04, 7.36MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  22%|██▏       | 7.86M/35.4M [00:01<00:03, 7.35MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  24%|██▍       | 8.58M/35.4M [00:01<00:03, 7.36MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  26%|██▌       | 9.28M/35.4M [00:01<00:03, 7.35MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  28%|██▊       | 9.98M/35.4M [00:01<00:03, 7.32MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  30%|███       | 10.7M/35.4M [00:01<00:03, 7.34MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  32%|███▏      | 11.4M/35.4M [00:01<00:03, 7.33MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  34%|███▍      | 12.1M/35.4M [00:01<00:03, 7.29MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  36%|███▋      | 12.8M/35.4M [00:01<00:03, 7.38MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  38%|███▊      | 13.5M/35.4M [00:01<00:03, 7.36MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  40%|████      | 14.3M/35.4M [00:02<00:03, 7.39MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  42%|████▏     | 15.0M/35.4M [00:02<00:02, 7.37MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  44%|████▍     | 15.7M/35.4M [00:02<00:02, 7.37MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  46%|████▋     | 16.4M/35.4M [00:02<00:02, 7.35MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  48%|████▊     | 17.1M/35.4M [00:02<00:02, 7.36MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  50%|█████     | 17.8M/35.4M [00:02<00:02, 7.37MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  52%|█████▏    | 18.5M/35.4M [00:02<00:02, 7.35MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  54%|█████▍    | 19.2M/35.4M [00:02<00:02, 7.34MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  56%|█████▋    | 20.0M/35.4M [00:02<00:02, 6.88MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  59%|█████▉    | 20.8M/35.4M [00:02<00:02, 7.41MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  61%|██████    | 21.5M/35.4M [00:03<00:01, 7.39MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  63%|██████▎   | 22.3M/35.4M [00:03<00:01, 7.36MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  65%|██████▍   | 23.0M/35.4M [00:03<00:01, 7.34MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  67%|██████▋   | 23.7M/35.4M [00:03<00:01, 7.36MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  69%|██████▉   | 24.4M/35.4M [00:03<00:01, 7.35MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  71%|███████   | 25.1M/35.4M [00:03<00:01, 7.36MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  73%|███████▎  | 25.8M/35.4M [00:03<00:01, 7.35MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  75%|███████▍  | 26.5M/35.4M [00:03<00:01, 7.33MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  77%|███████▋  | 27.2M/35.4M [00:03<00:01, 7.36MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  79%|███████▉  | 28.0M/35.4M [00:03<00:01, 7.37MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  81%|████████  | 28.7M/35.4M [00:04<00:00, 7.32MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  83%|████████▎ | 29.4M/35.4M [00:04<00:00, 7.33MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  85%|████████▍ | 30.1M/35.4M [00:04<00:00, 7.37MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  87%|████████▋ | 30.8M/35.4M [00:04<00:00, 7.35MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  89%|████████▉ | 31.5M/35.4M [00:04<00:00, 7.34MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  91%|█████████ | 32.2M/35.4M [00:04<00:00, 7.36MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  93%|█████████▎| 32.9M/35.4M [00:04<00:00, 7.36MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  95%|█████████▍| 33.6M/35.4M [00:04<00:00, 7.35MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz:  97%|█████████▋| 34.3M/35.4M [00:04<00:00, 7.34MiB/s]
# https://opendata.dwd.de/weather/local_forecasts/mos/MOSMIX_S/all_stations/kml/MOSMIX_S_LATEST_240.kmz: 100%|██████████| 35.4M/35.4M [00:05<00:00, 7.36MiB/s]
# 100%|██████████| 1/1 [00:10<00:00, 10.47s/it]
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-4-27f86ad440da> in <module>
# ----> 1 WetterVorhersage = WetterVorhersageNBG();
#
# c:\Users\j_kei\Documents\Git\Gesundheitsamt\Gesundheitsamt\DatenSammlung.py in WetterVorhersageNBG()
#      68     df['VALUE'] = df['VALUE'] - 273.15
#      69     df['date'] = df['DATE'].dt.date
# ---> 70     df = df.groupby('date').mean()
#      71     return df
#      72
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1391         Name: B, dtype: float64
#    1392         """
# -> 1393         return self._cython_agg_general(
#    1394             "mean",
#    1395             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1019         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#    1020     ) -> DataFrame:
# -> 1021         agg_blocks, agg_items = self._cython_agg_blocks(
#    1022             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1023         )
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1128
#    1129         if not (agg_blocks or split_frames):
# -> 1130             raise DataError("No numeric types to aggregate")
#    1131
#    1132         if split_items:
#
# DataError: No numeric types to aggregate

# %%
df_test = df

# %%
trainings_zeitraum_von = '2020-8-01'
df_test = df_test.loc[df_test.index>trainings_zeitraum_von].copy()

# %%
df_test.plot(title='Trainingsdaten am '+str(today))
# Out:
# <AxesSubplot:title={'center':'Trainingsdaten am 2021-04-15'}, xlabel='Date'>

# %%
df_test= df_test.rename(columns={"7TIW": "y"})
df_test = df_test.reset_index()
df_test= df_test.rename(columns={"Date": "ds"})

# %%
df_test
# Out:
#             ds           y  Temperatur  ResNbg
# 0   2020-08-03    5.598456        18.4   57.87
# 1   2020-08-04    4.633205        16.3   57.87
# 2   2020-08-05    4.247104        18.1   57.87
# 3   2020-08-06    4.633205        20.9   57.87
# 4   2020-08-07    3.861004        24.2   59.72
# ..         ...         ...         ...     ...
# 241 2021-04-10  192.664093        10.3   75.00
# 242 2021-04-11  205.212355        13.0   75.00
# 243 2021-04-12  205.598456         3.5   75.00
# 244 2021-04-13  203.281853         3.0   75.00
# 245 2021-04-14  204.633205         1.9   75.00
#
# [246 rows x 4 columns]

# %%
m = Prophet(changepoint_prior_scale=2)
m.add_country_holidays(country_name='DE')
m.add_regressor('Temperatur')
m.add_regressor('ResNbg')
m.fit(df_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0beab950422d> in <module>
#       3 m.add_regressor('Temperatur')
#       4 m.add_regressor('ResNbg')
# ----> 5 m.fit(df_test)
#
# NameError: name 'df_test' is not defined

# %%
#WetterVorhersage.head(20)

# %%
future = m.make_future_dataframe(periods=10,include_history=False)
future = future.set_index('ds')
#future.tail(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b967a1f8d6a1> in <module>
# ----> 1 future = m.make_future_dataframe(periods=10,include_history=False)
#       2 future = future.set_index('ds')
#       3 #future.tail(20)
#
# NameError: name 'm' is not defined

# %%
future['Temperatur'] = future.join(WetterVorhersage)
#future['Temperatur'] = 50
future['ResNbg'] = 75
future = future.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e3e7cf5781f6> in <module>
#       1 #future['Temperatur'] = future.join(WetterVorhersage)
# ----> 2 future['Temperatur'] = 50
#       3 future['ResNbg'] = 75
#       4 future = future.reset_index()
#
# NameError: name 'future' is not defined

# %%
#future.tail(20)

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#           ds        yhat  yhat_lower  yhat_upper
# 5 2021-04-18  225.583139  203.677950  246.395136
# 6 2021-04-19  230.564264  206.359939  254.755485
# 7 2021-04-20  234.793406  210.215467  259.935977
# 8 2021-04-21  233.920305  206.226287  261.998346
# 9 2021-04-22  238.557168  210.470364  270.426658

# %%
fig = m.plot(forecast)
ax = fig.gca()
ax.set_title(today, size=34)
fig.savefig('Vorhersagen/'+str(today)+'.png')
#plt.close(fig)

# %%
fig2 = m.plot_components(forecast)

# %%
#import gradio as gr


#def spectrogram(Restriktionen):
    #plt.rcParams["figure.figsize"] = (10,5)
    #plt.plot(forecast['ds'],forecast['yhat'])
    #return plt


#iface = gr.Interface(spectrogram, "slider", "plot")

#iface.test_launch()
#iface.launch()
